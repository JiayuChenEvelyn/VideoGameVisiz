# %% [markdown]
# ### EDA and generate implicit value

# %%
import pandas as pd
import numpy as np
import random

# %%
# generate implicit value

# %%
# 0.3 -   
data = pd.read_csv('steam_users.csv')
data['score'] = 5 + data['hours'].apply(lambda x: min(x,8)*5/8 + random.random()/20)
data['score'] = data['score'].apply(lambda x: min(x,10.00)).round(2)
data['implicit'] = data['buy'] + data['hours'].apply(lambda x: min((x-0.3),4)/10) + data['score'].apply(lambda x: (x-5)/20)
data['implicit'] = data['implicit'].round(2)


data['user_id'] = data['user_id'].astype('category').cat.codes
data['user_id'] = data['user_id'].apply(lambda x: 'old_'+str(x))
data.to_csv('steam_users_new.csv', index=False)

# %%
data
# Out:
#           user_id                     game_name  buy  play  hours  score  \
# 0           old_0                   Alien Swarm    1     1    4.9   8.07
# 1           old_0               Cities Skylines    1     1  144.0  10.00
# 2           old_0                Counter-Strike    1     0    0.0   5.04
# 3           old_0         Counter-Strike Source    1     0    0.0   5.03
# 4           old_0                 Day of Defeat    1     0    0.0   5.02
# ...           ...                           ...  ...   ...    ...    ...
# 128799  old_12389  Age of Empires II HD Edition    1     1    6.7   9.20
# 128800  old_12390  Counter-Strike Nexon Zombies    1     0    0.0   5.02
# 128801  old_12390                     Robocraft    1     0    0.0   5.03
# 128802  old_12391                        Dota 2    1     1    0.7   5.44
# 128803  old_12392                        Dota 2    1     1    0.2   5.15
#
#         implicit
# 0           1.55
# 1           1.65
# 2           0.97
# 3           0.97
# 4           0.97
# ...          ...
# 128799      1.61
# 128800      0.97
# 128801      0.97
# 128802      1.06
# 128803      1.00
#
# [128804 rows x 7 columns]

# %%
data['implicit'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
data['user_id'] = data['user_id'].astype('category').cat.codes
data['user_id'] = data['user_id'].apply(lambda x: 'old_'+str(x))
data
# Out:
#          user_id                     game_name  buy  play  hours  score  \
# 0          old_0                   Alien Swarm    1     1    4.9   8.07
# 1          old_0               Cities Skylines    1     1  144.0  10.00
# 2          old_0                Counter-Strike    1     0    0.0   5.04
# 3          old_0         Counter-Strike Source    1     0    0.0   5.03
# 4          old_0                 Day of Defeat    1     0    0.0   5.02
# ...          ...                           ...  ...   ...    ...    ...
# 128799  old_2657  Age of Empires II HD Edition    1     1    6.7   9.20
# 128800  old_2659  Counter-Strike Nexon Zombies    1     0    0.0   5.02
# 128801  old_2659                     Robocraft    1     0    0.0   5.03
# 128802  old_2660                        Dota 2    1     1    0.7   5.44
# 128803  old_2661                        Dota 2    1     1    0.2   5.15
#
#         implicit
# 0           1.55
# 1           1.65
# 2           0.97
# 3           0.97
# 4           0.97
# ...          ...
# 128799      1.61
# 128800      0.97
# 128801      0.97
# 128802      1.06
# 128803      1.00
#
# [128804 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128804 entries, 0 to 128803
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    128804 non-null  object
#  1   game_name  128804 non-null  object
#  2   buy        128804 non-null  int64
#  3   play       128804 non-null  int64
#  4   hours      128804 non-null  float64
#  5   score      128804 non-null  float64
#  6   implicit   128804 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 6.9+ MB

# %%
# data.to_csv('steam_users_new.csv', index=False)

# %%
# show hist of hours played ,maximum set 200

data['hours'].hist(bins=100, range=(0, 10))
# Out:
# <AxesSubplot:>
